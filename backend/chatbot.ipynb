# %%
import os
from langchain.llms import OpenAI
from langchain.chains import ConversationChain
from langchain.prompts import PromptTemplate
from langchain.memory import ConversationBufferMemory

# %%
os.environ["OPENAI_API_KEY"] = "sk-proj-nzz0ZbIxLLFUgp90F01-S8D1d8W0U9Jzp-cpOFP1DWGUb1me7kTi6tmugumuISSc4fu7lRfsQzT3BlbkFJBHopDdXlMszh7RMoO05OBO9zDMgh1vYrgnfUjd76O1OI4eo5ypGppaze9KGSudPGxLwzn6sRIAA"

# %%
llm = OpenAI(model_name="gpt-4o-mini")

# %%
conversation_memory = ConversationBufferMemory()
conversation_chain = ConversationChain(llm=llm, memory=conversation_memory)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Use the .run() method for conversation chains
response = conversation_chain.run("Hello! How can I assist you today?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Use the .run() method for conversation chains
# ----> 2 response = conversation_chain.run("Hello! How can I assist you today?")
#       3 print(response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain\chains\base.py:606, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     604     if len(args) != 1:
#     605         raise ValueError("`run` supports only one positional argument.")
# --> 606     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
# ...
